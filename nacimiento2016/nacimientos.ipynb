# %%
import pandas
txt = pandas.read_csv("/home/tania/Documentos/FinalProyectoB1/trabajo-final-primer-bimestre-final-008/nacimiento2016/ENV_2016.csv",encoding="cp1252",sep=",")

sexo = list((txt["sexo"]))
uniSex = list(set(sexo))
num1=sexo.count(uniSex[0])
num2 = sexo.count(uniSex[1])

from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

fruits = uniSex
counts = [num1,num2]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))

p = figure(x_range=fruits, plot_height=350, toolbar_location=None, title="Número de sexo")
p.vbar(x='fruits', top='counts', width=0.4, source=source, legend="fruits",
       line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = num1+20000
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# /home/tania/Documentos/Entornos/programacion/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (1,2,3,5,12,13,14,16,17,27,29,31,32,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mes = list((txt["mes_nac"]))
uniMes = list(set(mes))

mes1 = mes.count(uniMes[0])
mes2 = mes.count(uniMes[1])
mes3 = mes.count(uniMes[2])
mes4 = mes.count(uniMes[3])
mes5 = mes.count(uniMes[4])
mes6 = mes.count(uniMes[5])
mes7 = mes.count(uniMes[6])
mes8 = mes.count(uniMes[7])
mes9 = mes.count(uniMes[8])
mes10 = mes.count(uniMes[9])
mes11 = mes.count(uniMes[10])
mes12 = mes.count(uniMes[11])

lista=[mes1,mes2,mes3,mes4,mes5,mes6,mes7,mes8,mes9,mes10,mes11,mes12]

p =   figure(x_range= uniMes, plot_width=1000,plot_height=300, title="Cantidad de nacimientos por mes", toolbar_location="below", tools="")
p.vbar(x=uniMes, top = lista,width=0.6)
p.xgrid.grid_line_color= None
p.y_range.start=0

show(p)

# %%
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure
from bokeh.transform import factor_cmap


div = list(set(list((txt["mes_insc"]))))
group = list(set(list((txt["prov_insc"]))))

place1=[]
place2=[]
place3=[] 

fruits = group[0:6]
years = div[0:3]

for i in range(6):
    place1.append(len(txt[(txt["mes_insc"] == div[0]) & (txt["prov_insc"] == group[i])]))
    place2.append(len(txt[(txt["mes_insc"] == div[1]) & (txt["prov_insc"] == group[i])]))
    place3.append(len(txt[(txt["mes_insc"] == div[2]) & (txt["prov_insc"] == group[i])]))

data = {'fruits' : fruits,
        'place1'   : place1,
        'place2'   : place2,
        'place3'   : place3}

palette = ["#c9d9d3", "#718dbf", "#e84d60"]

x = [ (fruit, year) for fruit in fruits for year in years ]
counts = sum(zip(data['place1'], data['place2'], data['place3']), ())

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x),  plot_width=1000,plot_height=300, title="Cantidad de inscripciones por mes en cada provincia",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source, line_color="white",
       fill_color=factor_cmap('x', palette=palette, factors=years, start=1, end=2))

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None

show(p)

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

nivelInstru = list(set(list((txt["niv_inst"]))))
uniEdad = list(set(list(map(str, (list(set(list((txt["edad_mad"])))))))))

fruits = nivelInstru[0:6]
years = uniEdad[0:3]

colors = ["#c9d9d3", "#718dbf", "#e84d60"]
edad1 = []
edad2 = []
edad3 = []
for i in range(6):
    edad1.append(len(txt[(txt["edad_mad"] == uniEdad[0]) & (txt["niv_inst"] == nivelInstru[i])]))
    edad2.append(len(txt[(txt["edad_mad"] == uniEdad[1]) & (txt["niv_inst"] == nivelInstru[i])]))
    edad3.append(len(txt[(txt["edad_mad"] == uniEdad[2]) & (txt["niv_inst"] == nivelInstru[i])]))


data = {'fruits' : fruits,
        uniEdad[0]   : edad1,
        uniEdad[1]   : edad2,
        uniEdad[2]   : edad3}

source = ColumnDataSource(data=data)

p = figure(x_range=fruits,plot_width=1000,plot_height=700, title="Conteo de edad y nivel de estudio",
           toolbar_location=None, tools="")

p.vbar_stack(years, x='fruits', width=0.9, color=colors, source=source,
             legend=[value(x) for x in years])

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)

# %%
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource
from bokeh.palettes import GnBu3, OrRd3
from bokeh.plotting import figure

etnia = list(set(list((txt["etnia"]))))
etnia.remove("Sin información")
civil= (list(set(list((txt["est_civil"])))))

fruits = etnia[0:6]
years = civil[0:3]

etnia1 = []
etnia2 = []
etnia3 = []

for i in range(6):
    etnia1.append(len(txt[(txt["est_civil"] == civil[0]) & (txt["etnia"] == etnia[i])]))
    etnia2.append(len(txt[(txt["est_civil"] == civil[1]) & (txt["etnia"] == etnia[i])]))
    etnia3.append(len(txt[(txt["est_civil"] == civil[2]) & (txt["etnia"] == etnia[i])]))


exports = {'fruits' : fruits,
        civil[0]   : etnia1,
        civil[1]   : etnia2,
        civil[2]   : etnia3}

tam = max(etnia1)+max(etnia2)+max(etnia3)
tams = min(etnia1)+min(etnia2)+min(etnia3)

p = figure(y_range=fruits,  plot_width=900,plot_height=600, x_range=(tams*-10, tam), title="Conteo de estado civil y etnia",
           toolbar_location=None)

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3, source=ColumnDataSource(exports),
             legend=["%s ." % x for x in years])

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3 , source=ColumnDataSource(exports))
p.y_range.range_padding = 0.1
p.ygrid.grid_line_color = None
p.legend.location = "top_left"
p.axis.minor_tick_line_color = None
p.outline_line_color = None

show(p)

# %%
talla peso
# Out:
#   File "<ipython-input-4-f1b6759b504f>", line 1
#     talla peso
#              ^
# SyntaxError: invalid syntax

# %%
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource
from bokeh.palettes import GnBu3, OrRd3
from bokeh.plotting import figure

uniTalla = list(set(list(map(str, (list(set(list((txt["talla"])))))))))
uniTalla.remove("Sin información")
uniPeso = list(set(list(map(str, (list(set(list((txt["peso"])))))))))
uniPeso.remove("Sin información")

fruits = uniTalla[0:6]
years = uniPeso[0:3]

uniTalla1 = []
uniTalla2 = []
uniTalla3 = []

for i in range(6):
    uniTalla1.append(len(txt[(txt["peso"] == uniPeso[0]) & (txt["talla"] == uniTalla[i])]))
    uniTalla2.append(len(txt[(txt["peso"] == uniPeso[1]) & (txt["talla"] == uniTalla[i])]))
    uniTalla3.append(len(txt[(txt["peso"] == uniPeso[2]) & (txt["talla"] == uniTalla[i])]))


exports = {'fruits' : fruits,
        uniPeso[0]   : uniTalla1,
        uniPeso[1]   : uniTalla2,
        uniPeso[2]   : uniTalla3}

tam1 = max(uniTalla1)+max(uniTalla2)+max(uniTalla3)
tams1 = min(uniTalla1)+min(uniTalla2)+min(uniTalla3)

p = figure(y_range=fruits,  plot_width=1000,plot_height=700, x_range=(tams1*-10, tam1), title="Conteo de peso y talla",
           toolbar_location=None)

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3, source=ColumnDataSource(exports),
             legend=["%s ." % x for x in years])

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3 , source=ColumnDataSource(exports))
p.y_range.range_padding = 0.1
p.ygrid.grid_line_color = None
p.legend.location = "top_left"
p.axis.minor_tick_line_color = None
p.outline_line_color = None

show(p)

# %%
uniPeso
# Out:
# ['3381',
#  '2380',
#  '1655',
#  '2798',
#  '2745',
#  '2676',
#  '2005',
#  '1905',
#  '3878',
#  '3369',
#  '1996',
#  '3478',
#  '1085',
#  '3644',
#  '2184',
#  '815',
#  '1730',
#  '3299',
#  '2188',
#  '2924',
#  '2941',
#  '1075',
#  '4990',
#  '3385',
#  '4710',
#  '3097',
#  '2816',
#  '530',
#  '3795',
#  '3317',
#  '895',
#  '1877',
#  '2246',
#  '4612',
#  '1365',
#  '1662',
#  '3004',
#  '3079',
#  '2428',
#  '4476',
#  '4150',
#  '3181',
#  '2163',
#  '3075',
#  '1462',
#  '2593',
#  '2098',
#  '726',
#  '2318',
#  '4250',
#  '3451',
#  '3638',
#  '1234',
#  '2858',
#  '2957',
#  '1338',
#  '2991',
#  '2025',
#  '3766',
#  '1904',
#  '2355',
#  '1238',
#  '3830',
#  '4556',
#  '800',
#  '3213',
#  '994',
#  '4056',
#  '3775',
#  '3267',
#  '3515',
#  '3467',
#  '4725',
#  '1635',
#  '1454',
#  '1698',
#  '4000',
#  '1327',
#  '2134',
#  '2940',
#  '3076',
#  '2295',
#  '2118',
#  '1610',
#  '2154',
#  '3940',
#  '1464',
#  '1582',
#  '3738',
#  '2993',
#  '4076',
#  '2353',
#  '1772',
#  '3405',
#  '2830',
#  '2600',
#  '4236',
#  '1386',
#  '3355',
#  '2392',
#  '2642',
#  '3443',
#  '1818',
#  '2228',
#  '4241',
#  '3365',
#  '1420',
#  '3078',
#  '3348',
#  '1394',
#  '3534',
#  '3425',
#  '2587',
#  '4730',
#  '1628',
#  '3474',
#  '2303',
#  '3530',
#  '3873',
#  '1821',
#  '4314',
#  '700',
#  '2874',
#  '3314',
#  '2029',
#  '1052',
#  '4210',
#  '2160',
#  '4371',
#  '3922',
#  '1152',
#  '3123',
#  '3027',
#  '2011',
#  '2820',
#  '2259',
#  '3541',
#  '3770',
#  '4146',
#  '4047',
#  '3634',
#  '2867',
#  '1510',
#  '2393',
#  '3698',
#  '826',
#  '1965',
#  '2502',
#  '3155',
#  '3688',
#  '3798',
#  '3150',
#  '3461',
#  '4015',
#  '3853',
#  '1636',
#  '3606',
#  '998',
#  '3996',
#  '3636',
#  '4432',
#  '1816',
#  '1058',
#  '3245',
#  '2249',
#  '3410',
#  '2888',
#  '2844',
#  '3640',
#  '3157',
#  '4110',
#  '1670',
#  '2589',
#  '3437',
#  '2043',
#  '3013',
#  '984',
#  '3199',
#  '4095',
#  '1120',
#  '4028',
#  '3870',
#  '3507',
#  '1414',
#  '2879',
#  '3942',
#  '2431',
#  '4283',
#  '3964',
#  '2499',
#  '1090',
#  '2483',
#  '4230',
#  '3321',
#  '2162',
#  '1514',
#  '2822',
#  '2126',
#  '3754',
#  '3619',
#  '3219',
#  '2313',
#  '4295',
#  '3887',
#  '2214',
#  '2389',
#  '2150',
#  '3612',
#  '4535',
#  '864',
#  '2915',
#  '3812',
#  '2778',
#  '3805',
#  '2077',
#  '4770',
#  '3713',
#  '560',
#  '3990',
#  '4366',
#  '1535',
#  '3148',
#  '1795',
#  '2205',
#  '2573',
#  '3863',
#  '3085',
#  '1936',
#  '2750',
#  '3366',
#  '3466',
#  '3521',
#  '3676',
#  '3555',
#  '2622',
#  '3261',
#  '3557',
#  '2925',
#  '4086',
#  '1604',
#  '3539',
#  '3732',
#  '2921',
#  '2512',
#  '2566',
#  '1199',
#  '3504',
#  '2802',
#  '4422',
#  '4355',
#  '706',
#  '4420',
#  '775',
#  '1986',
#  '1012',
#  '1831',
#  '710',
#  '3380',
#  '2783',
#  '1172',
#  '2103',
#  '2346',
#  '1984',
#  '3932',
#  '1812',
#  '3627',
#  '1880',
#  '2630',
#  '2719',
#  '1197',
#  '4986',
#  '3325',
#  '3389',
#  '3749',
#  '1322',
#  '1114',
#  '3338',
#  '3804',
#  '1726',
#  '3183',
#  '3278',
#  '1250',
#  '4223',
#  '3303',
#  '4144',
#  '4505',
#  '3337',
#  '2244',
#  '3615',
#  '3576',
#  '3509',
#  '4200',
#  '2525',
#  '3249',
#  '3452',
#  '795',
#  '2153',
#  '3456',
#  '625',
#  '3251',
#  '755',
#  '4305',
#  '3609',
#  '3645',
#  '2724',
#  '2327',
#  '3553',
#  '2006',
#  '2894',
#  '955',
#  '4118',
#  '3406',
#  '3087',
#  '3037',
#  '3818',
#  '3352',
#  '3129',
#  '1159',
#  '2537',
#  '2612',
#  '1192',
#  '3573',
#  '4001',
#  '1375',
#  '3409',
#  '2845',
#  '4119',
#  '2419',
#  '3803',
#  '3073',
#  '1363',
#  '3846',
#  '2225',
#  '1101',
#  '1563',
#  '4165',
#  '3489',
#  '1895',
#  '1674',
#  '3373',
#  '2692',
#  '3631',
#  '3762',
#  '3896',
#  '3061',
#  '3007',
#  '3891',
#  '3274',
#  '1750',
#  '4115',
#  '3544',
#  '3554',
#  '3026',
#  '1268',
#  '3624',
#  '1170',
#  '782',
#  '1225',
#  '4470',
#  '3045',
#  '1046',
#  '3607',
#  '4038',
#  '1305',
#  '3254',
#  '1236',
#  '3548',
#  '2381',
#  '3340',
#  '4465',
#  '660',
#  '2903',
#  '2631',
#  '4618',
#  '2473',
#  '2619',
#  '1890',
#  '3376',
#  '3729',
#  '2471',
#  '4132',
#  '3558',
#  '2329',
#  '2604',
#  '3051',
#  '2774',
#  '3569',
#  '3970',
#  '4060',
#  '3162',
#  '3112',
#  '3131',
#  '4051',
#  '1166',
#  '2690',
#  '2632',
#  '1844',
#  '2694',
#  '3785',
#  '2180',
#  '2646',
#  '4070',
#  '2967',
#  '2805',
#  '2022',
#  '2533',
#  '2599',
#  '2711',
#  '2367',
#  '2572',
#  '2540',
#  '3844',
#  '3130',
#  '2054',
#  '1602',
#  '2100',
#  '1746',
#  '3501',
#  '4403',
#  '4130',
#  '1446',
#  '2211',
#  '1122',
#  '2945',
#  '3227',
#  '2863',
#  '2900',
#  '3003',
#  '1370',
#  '3256',
#  '2088',
#  '2810',
#  '3477',
#  '4742',
#  '720',
#  '2970',
#  '2501',
#  '3647',
#  '1240',
#  '2667',
#  '3266',
#  '4042',
#  '2383',
#  '2873',
#  '1959',
#  '3583',
#  '2475',
#  '4178',
#  '2907',
#  '4665',
#  '2399',
#  '3722',
#  '1585',
#  '3706',
#  '3525',
#  '4410',
#  '3110',
#  '2662',
#  '1862',
#  '1465',
#  '2084',
#  '4183',
#  '2335',
#  '2571',
#  '4190',
#  '4330',
#  '4681',
#  '3391',
#  '2793',
#  '1851',
#  '2553',
#  '3008',
#  '1790',
#  '1704',
#  '1541',
#  '2122',
#  '630',
#  '845',
#  '540',
#  '2095',
#  '4301',
#  '1615',
#  '780',
#  '1062',
#  '1065',
#  '1390',
#  '2806',
#  '635',
#  '4720',
#  '4228',
#  '3695',
#  '2266',
#  '3776',
#  '986',
#  '4402',
#  '3262',
#  '2757',
#  '610',
#  '3136',
#  '3843',
#  '2330',
#  '2748',
#  '3396',
#  '4767',
#  '3246',
#  '3471',
#  '2013',
#  '2314',
#  '820',
#  '2938',
#  '2445',
#  '1852',
#  '2767',
#  '2140',
#  '2870',
#  '958',
#  '1158',
#  '2658',
#  '3984',
#  '1431',
#  '3378',
#  '3084',
#  '750',
#  '2984',
#  '2543',
#  '2326',
#  '2919',
#  '3402',
#  '2493',
#  '1710',
#  '2598',
#  '4020',
#  '879',
#  '4050',
#  '2003',
#  '1665',
#  '2057',
#  '2309',
#  '2345',
#  '4655',
#  '1242',
#  '1030',
#  '1360',
#  '3065',
#  '3308',
#  '1424',
#  '900',
#  '3330',
#  '645',
#  '4334',
#  '3742',
#  '3519',
#  '2897',
#  '1534',
#  '4570',
#  '1916',
#  '4605',
#  '2551',
#  '1918',
#  '3666',
#  '3689',
#  '500',
#  '2347',
#  '3727',
#  '2672',
#  '3750',
#  '910',
#  '3164',
#  '3149',
#  '2800',
#  '2229',
#  '3089',
#  '4870',
#  '2400',
#  '1574',
#  '2876',
#  '2860',
#  '3767',
#  '4100',
#  '3016',
#  '1555',
#  '790',
#  '3741',
#  '1413',
#  '1910',
#  '714',
#  '2284',
#  '2971',
#  '2640',
#  '2617',
#  '4237',
#  '1156',
#  '1644',
#  '1125',
#  '3480',
#  '2851',
#  '1970',
#  '2614',
#  '902',
#  '3145',
#  '2764',
#  '3141',
#  '4495',
#  '3152',
#  '3058',
#  '3563',
#  '3975',
#  '3439',
#  '2875',
#  '1736',
#  '1004',
#  '2545',
#  '2252',
#  '3929',
#  '2939',
#  '4362',
#  '2998',
#  '565',
#  '2034',
#  '1997',
#  '1869',
#  '3912',
#  '3386',
#  '4835',
#  '3653',
#  '3788',
#  '2494',
#  '3764',
#  '2108',
#  '2581',
#  '1124',
#  '3053',
#  '3032',
#  '3777',
#  '1955',
#  '4187',
#  '3499',
#  '3705',
#  '670',
#  '3661',
#  '3180',
#  '2905',
#  '3115',
#  '3935',
#  '1400',
#  '2826',
#  '1560',
#  '1134',
#  '2056',
#  '4215',
#  '2637',
#  '3694',
#  '4181',
#  '1981',
#  '2799',
#  '3336',
#  '1160',
#  '4039',
#  '2253',
#  '3968',
#  '2713',
#  '2024',
#  '2161',
#  '2498',
#  '745',
#  '3600',
#  '2440',
#  '3944',
#  '2707',
#  '3586',
#  '1764',
#  '1136',
#  '1968',
#  '2376',
#  '4478',
#  '2705',
#  '3514',
#  '2040',
#  '3250',
#  '2517',
#  '2148',
#  '2609',
#  '2546',
#  '2535',
#  '3482',
#  '3302',
#  '2538',
#  '1664',
#  '1630',
#  '731',
#  '2989',
#  '2594',
#  '3275',
#  '704',
#  '2278',
#  '4136',
#  '1405',
#  '3966',
#  '1536',
#  '3860',
#  '1690',
#  '2772',
#  '3603',
#  '2405',
#  '1475',
#  '3476',
#  '3858',
#  '1524',
#  '2771',
#  '2946',
#  '4227',
#  '2650',
#  '1182',
#  '2932',
#  '1368',
#  '3736',
#  '940',
#  '2272',
#  '860',
#  '1768',
#  '3890',
#  '3242',
#  '2586',
#  '2444',
#  '2963',
#  '2933',
#  '2378',
#  '2402',
#  '1115',
#  '1882',
#  '999',
#  '1832',
#  '3497',
#  '3031',
#  '3879',
#  '3552',
#  '4375',
#  '4268',
#  '4620',
#  '2813',
#  '2615',
#  '1110',
#  '580',
#  '945',
#  '3313',
#  '3936',
#  '3845',
#  '3748',
#  '4244',
#  '3657',
#  '1395',
#  '2570',
#  '3751',
#  '4055',
#  '3745',
#  '3663',
#  '1434',
#  '1759',
#  '4391',
#  '2472',
#  '1029',
#  '2176',
#  '722',
#  '885',
#  '3358',
#  '3359',
#  '2273',
#  '3464',
#  '1374',
#  '4750',
#  '2073',
#  '3955',
#  '2185',
#  '4176',
#  '2422',
#  '2547',
#  '870',
#  '2198',
#  '1472',
#  '2861',
#  '2083',
#  '3807',
#  '2004',
#  '2065',
#  '1843',
#  '2085',
#  '1808',
#  '2706',
#  '4925',
#  '3872',
#  '4238',
#  '1806',
#  '1649',
#  '3154',
#  '1919',
#  '1426',
#  '3543',
#  '3961',
#  '3324',
#  '605',
#  '2854',
#  '2695',
#  '3033',
#  '3054',
#  '3712',
#  '1994',
#  '884',
#  '1781',
#  '1794',
#  '3276',
#  '3272',
#  '2583',
#  '1508',
#  '3491',
#  '1830',
#  '3374',
#  '3721',
#  '2128',
#  '2332',
#  '566',
#  '3135',
#  '2953',
#  '3399',
#  '1694',
#  '2092',
#  '1494',
#  '4424',
#  '4455',
#  '1538',
#  '3900',
#  '3419',
#  '1078',
#  '2559',
#  '3865',
#  '4700',
#  '1252',
#  '2465',
#  '4602',
#  '4019',
#  '4170',
#  '3191',
#  '1350',
#  '3296',
#  '3593',
#  '3537',
#  '2653',
#  '1227',
#  '1884',
#  '2607',
#  '542',
#  '4468',
#  '1885',
#  '4264',
#  '4920',
#  '3014',
#  '3945',
#  '806',
#  '1438',
#  '646',
#  '3144',
#  '3680',
#  '2633',
#  '3041',
#  '2509',
#  '3595',
#  '968',
#  '2406',
#  '1422',
#  '1364',
#  '3460',
#  '2124',
#  '3540',
#  '2996',
#  '1440',
#  '1775',
#  '2146',
#  '3574',
#  '2635',
#  '2856',
#  '1712',
#  '3390',
#  '2680',
#  '1348',
#  '532',
#  '964',
#  '2504',
#  '830',
#  '2789',
#  '1684',
#  '3635',
#  '3223',
#  '1595',
#  '3692',
#  '2814',
#  '2871',
#  '1332',
#  '3934',
#  '1926',
#  '2505',
#  '620',
#  '2663',
#  '2319',
#  '3375',
#  '2841',
#  '3283',
#  '3810',
#  '4203',
#  '4016',
#  '3318',
#  '2255',
#  '618',
#  '2973',
#  '2608',
#  '2696',
#  '974',
#  '2954',
#  '3513',
#  '2104',
#  '2394',
#  '3496',
#  '1325',
#  '2819',
#  '2078',
#  '1230',
#  '2746',
#  '3919',
#  '2859',
#  '4980',
#  '3234',
#  '3752',
#  '3728',
#  '3109',
#  '2691',
#  '3783',
#  '3924',
#  '3502',
#  '3201',
#  '3185',
#  '3345',
#  '2737',
#  '3287',
#  '2375',
#  '4182',
#  '4265',
#  '2156',
#  '2265',
#  '1320',
#  '1755',
#  '3485',
#  '4125',
#  '3684',
#  '2792',
#  '3200',
#  '1076',
#  '2557',
#  '2623',
#  '2306',
#  '3069',
#  '2956',
#  '3523',
#  '2182',
#  '1154',
#  '1179',
#  '2020',
#  '788',
#  '2817',
#  '3351',
#  '3933',
#  '3160',
#  '3072',
#  '3119',
#  '3702',
#  '3487',
#  '1480',
#  '2909',
#  '2769',
#  '4485',
#  '4680',
#  '3562',
#  '2351',
#  '4850',
#  '1356',
#  '822',
#  '2421',
#  '4256',
#  '4464',
#  '2074',
#  '2410',
#  '3604',
#  '1988',
#  '1805',
#  '2435',
#  '4048',
#  '3522',
#  '4342',
#  '1100',
#  '3248',
#  '3772',
#  '1578',
#  '2002',
#  ...]
