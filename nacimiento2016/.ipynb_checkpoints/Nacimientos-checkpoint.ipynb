# %%
import pandas
txt = pandas.read_csv("/home/tania/Documentos/FinalProyectoB1/trabajo-final-primer-bimestre-final-008/nacimiento2016/ENV_2016.csv",encoding="cp1252",sep=",")
sexo = list((txt["sexo"]))
uniSex = list(set(sexo))
num1=sexo.count(uniSex[0])
num2 = sexo.count(uniSex[1])

from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

fruits = uniSex
counts = [num1,num2]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))

p = figure(x_range=fruits, plot_height=350, toolbar_location=None, title="Número de sexo")
p.vbar(x='fruits', top='counts', width=0.4, source=source, legend="fruits",
       line_color='white', fill_color=factor_cmap('fruits', palette=Spectral6, factors=fruits))

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = num1+20000
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# /home/tania/Documentos/Entornos/programacion/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (1,2,3,5,12,13,14,16,17,27,29,31,32,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mes = list((txt["mes_nac"]))
uniMes = list(set(mes))
num1m=mes.count(uniMes[0])
num2m = mes.count(uniMes[1])
num3=mes.count(uniMes[2])
num4 = mes.count(uniMes[3])
num5=mes.count(uniMes[4])
num6 = mes.count(uniMes[5])
num7=mes.count(uniMes[6])
num8 = mes.count(uniMes[7])
num9=mes.count(uniMes[8])
num10 = mes.count(uniMes[9])
num11=mes.count(uniMes[10])
num12 = mes.count(uniMes[11])
lista=[num1m,num2m,num3,num4,num5,num6,num7,num8,num9,num10,num11,num12]
p =   figure(x_range= uniMes, plot_width=1000,plot_height=300, title="Cantidad de nacimientos por mes", toolbar_location="below", tools="")
p.vbar(x=uniMes, top = lista,width=0.6)
p.xgrid.grid_line_color= None
p.y_range.start=0
show(p)

# %%
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure
from bokeh.transform import factor_cmap

edad = list(txt["edad_mad"])
uniEdad = list(set(list(map(str, list(set(edad))))))
nivelInstru = list(list(txt["niv_inst"]))

div = list(set(list((txt["mes_insc"]))))
group = list(set(list((txt["prov_insc"]))))
place1=[]
place2=[]
place3=[]
for i in range(6):
    place1.append(len(txt[(txt["mes_insc"] == div[0]) & (txt["prov_insc"] == group[i])]))
    place2.append(len(txt[(txt["mes_insc"] == div[1]) & (txt["prov_insc"] == group[i])]))
    place3.append(len(txt[(txt["mes_insc"] == div[2]) & (txt["prov_insc"] == group[i])]))

fruits = group[0:6]
years = div[0:3]

data = {'fruits' : fruits,
        'place1'   : place1,
        'place2'   : place2,
        'place3'   : place3}

palette = ["#c9d9d3", "#718dbf", "#e84d60"]

x = [ (fruit, year) for fruit in fruits for year in years ]
counts = sum(zip(data['place1'], data['place2'], data['place3']), ())

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x),  plot_width=1000,plot_height=300, title="Cantidad de inscripciones por mes en cada provincia",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source, line_color="white",
       fill_color=factor_cmap('x', palette=palette, factors=years, start=1, end=2))

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None

show(p)

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

nivelInstru = list(set(list((txt["niv_inst"]))))
uniEdad = list(set(list(map(str, (list(set(list((txt["edad_mad"])))))))))

fruits = nivelInstru[0:6]
years = uniEdad[0:3]

colors = ["#c9d9d3", "#718dbf", "#e84d60"]
edad1= []
edad2 =[]
edad3=[]
for i in range(6):
    edad1.append(len(txt[(txt["edad_mad"] == uniEdad[0]) & (txt["niv_inst"] == nivelInstru[i])]))
    edad2.append(len(txt[(txt["edad_mad"] == uniEdad[1]) & (txt["niv_inst"] == nivelInstru[i])]))
    edad3.append(len(txt[(txt["edad_mad"] == uniEdad[2]) & (txt["niv_inst"] == nivelInstru[i])]))


data = {'fruits' : fruits,
        uniEdad[0]   : edad1,
        uniEdad[1]   : edad2,
        uniEdad[2]   : edad3}

source = ColumnDataSource(data=data)

p = figure(x_range=fruits,plot_width=1000,plot_height=700, title="Conteo de edad y nivel de estudio",
           toolbar_location=None, tools="")

p.vbar_stack(years, x='fruits', width=0.9, color=colors, source=source,
             legend=[value(x) for x in years])

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)

# %%
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource
from bokeh.palettes import GnBu3, OrRd3
from bokeh.plotting import figure

etnia = list(set(list((txt["etnia"]))))
etnia.remove("Sin información")
civil= (list(set(list((txt["est_civil"])))))

fruits = etnia[0:6]
years = civil[0:3]

etnia1= []
etnia2 =[]
etnia3=[]
for i in range(6):
    etnia1.append(len(txt[(txt["est_civil"] == civil[0]) & (txt["etnia"] == etnia[i])]))
    etnia2.append(len(txt[(txt["est_civil"] == civil[1]) & (txt["etnia"] == etnia[i])]))
    etnia3.append(len(txt[(txt["est_civil"] == civil[2]) & (txt["etnia"] == etnia[i])]))


exports = {'fruits' : fruits,
        civil[0]   : etnia1,
        civil[1]   : etnia2,
        civil[2]   : etnia3}
tam = max(etnia1)+max(etnia2)+max(etnia3)
tams = min(etnia1)+min(etnia2)+min(etnia3)
p = figure(y_range=fruits,  plot_width=900,plot_height=600, x_range=(tams*-10, tam), title="Conteo de edad y nivel de estudio",
           toolbar_location=None)

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3, source=ColumnDataSource(exports),
             legend=["%s ." % x for x in years])

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3 , source=ColumnDataSource(exports))
p.y_range.range_padding = 0.1
p.ygrid.grid_line_color = None
p.legend.location = "top_left"
p.axis.minor_tick_line_color = None
p.outline_line_color = None

show(p)

# %%
talla peso
# Out:
# 7694

# %%
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource
from bokeh.palettes import GnBu3, OrRd3
from bokeh.plotting import figure

uniTalla = list(set(list(map(str, (list(set(list((txt["talla"])))))))))
uniTalla.remove("Sin información")
uniPeso= list(set(list(map(str, (list(set(list((txt["peso"])))))))))
uniPeso.remove("Sin información")

fruits = uniTalla[0:6]
years = uniPeso[0:3]

etnia11= []
etnia21 =[]
etnia31=[]
for i in range(6):
    etnia11.append(len(txt[(txt["peso"] == uniPeso[0]) & (txt["talla"] == uniTalla[i])]))
    etnia21.append(len(txt[(txt["peso"] == uniPeso[1]) & (txt["talla"] == uniTalla[i])]))
    etnia31.append(len(txt[(txt["peso"] == uniPeso[2]) & (txt["talla"] == uniTalla[i])]))


exports = {'fruits' : fruits,
        uniPeso[0]   : etnia11,
        uniPeso[1]   : etnia21,
        uniPeso[2]   : etnia31}
tam1 = max(etnia1)+max(etnia2)+max(etnia3)
tams1 = min(etnia1)+min(etnia2)+min(etnia3)
p = figure(y_range=fruits,  plot_width=900,plot_height=600, x_range=(tams1*-10, tam1), title="Conteo de edad y nivel de estudio",
           toolbar_location=None)

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3, source=ColumnDataSource(exports),
             legend=["%s ." % x for x in years])

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3 , source=ColumnDataSource(exports))
p.y_range.range_padding = 0.1
p.ygrid.grid_line_color = None
p.legend.location = "top_left"
p.axis.minor_tick_line_color = None
p.outline_line_color = None

show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-986e3cbec992> in <module>()
#      25         uniPeso[1]   : etnia21,
#      26         uniPeso[2]   : etnia31}
# ---> 27 tam1 = max(etnia1)+max(etnia2)+max(etnia3)
#      28 tams1 = min(etnia1)+min(etnia2)+min(etnia3)
#      29 p = figure(y_range=fruits,  plot_width=900,plot_height=600, x_range=(tams1*-10, tam1), title="Conteo de edad y nivel de estudio",
#
# NameError: name 'etnia1' is not defined

# %%
uniPeso
# Out:
# ['2396',
#  '1882',
#  '3164',
#  '2288',
#  '3377',
#  '4263',
#  '3800',
#  '4755',
#  '4610',
#  '3282',
#  '3511',
#  '3441',
#  '3741',
#  '3969',
#  '3629',
#  '2008',
#  '4822',
#  '4135',
#  '4690',
#  '3214',
#  '2523',
#  '3246',
#  '915',
#  '3221',
#  '1690',
#  '3641',
#  '3579',
#  '3574',
#  '888',
#  '2686',
#  '605',
#  '1136',
#  '2619',
#  '3241',
#  '3063',
#  '2612',
#  '2744',
#  '576',
#  '3987',
#  '2087',
#  '1988',
#  '2835',
#  '2367',
#  '2717',
#  '3482',
#  '3457',
#  '4080',
#  '4290',
#  '2196',
#  '896',
#  '2938',
#  '1910',
#  '3502',
#  '2332',
#  '1154',
#  '2786',
#  '2702',
#  '3156',
#  '2414',
#  '2998',
#  '1485',
#  '2392',
#  '3585',
#  '2928',
#  '1869',
#  '1324',
#  '1698',
#  '2695',
#  '2773',
#  '1985',
#  '3255',
#  '1630',
#  '3559',
#  '2312',
#  '3887',
#  '1638',
#  '2891',
#  '3804',
#  '1875',
#  '2873',
#  '3487',
#  '2029',
#  '3965',
#  '4098',
#  '1970',
#  '1586',
#  '3504',
#  '3087',
#  '3947',
#  '720',
#  '3996',
#  '3584',
#  '3008',
#  '2890',
#  '4020',
#  '1944',
#  '2741',
#  '3950',
#  '3456',
#  '2483',
#  '1550',
#  '4050',
#  '1325',
#  '2445',
#  '1480',
#  '1332',
#  '3778',
#  '1863',
#  '1475',
#  '974',
#  '670',
#  '1541',
#  '2385',
#  '2908',
#  '2762',
#  '2210',
#  '3496',
#  '2943',
#  '1260',
#  '2992',
#  '4070',
#  '2204',
#  '2623',
#  '4006',
#  '4240',
#  '2576',
#  '2024',
#  '2289',
#  '1816',
#  '2462',
#  '3203',
#  '3266',
#  '4396',
#  '3935',
#  '3042',
#  '1652',
#  '1684',
#  '2630',
#  '4181',
#  '2951',
#  '4572',
#  '2641',
#  '1514',
#  '2956',
#  '4060',
#  '1576',
#  '3801',
#  '4965',
#  '4325',
#  '2640',
#  '3145',
#  '3275',
#  '2711',
#  '1904',
#  '3674',
#  '2887',
#  '1388',
#  '3765',
#  '2667',
#  '1408',
#  '1175',
#  '3053',
#  '2845',
#  '3844',
#  '3784',
#  '3716',
#  '4545',
#  '3758',
#  '3527',
#  '2653',
#  '3657',
#  '3668',
#  '3355',
#  '4310',
#  '2778',
#  '4157',
#  '2826',
#  '3138',
#  '3426',
#  '1968',
#  '814',
#  '3656',
#  '2750',
#  '1668',
#  '2057',
#  '3604',
#  '3468',
#  '1058',
#  '2206',
#  '2043',
#  '3554',
#  '3119',
#  '3850',
#  '3999',
#  '4502',
#  '4245',
#  '3369',
#  '2122',
#  '2247',
#  '4930',
#  '2217',
#  '2514',
#  '3658',
#  '3121',
#  '3152',
#  '1400',
#  '2979',
#  '2137',
#  '3323',
#  '3230',
#  '2995',
#  '3655',
#  '1180',
#  '3799',
#  '2025',
#  '545',
#  '3334',
#  '965',
#  '2360',
#  '1716',
#  '4548',
#  '2539',
#  '3665',
#  '3693',
#  '3899',
#  '2805',
#  '2769',
#  '1356',
#  '2961',
#  '3345',
#  '2452',
#  '3900',
#  '1765',
#  '1916',
#  '4208',
#  '3398',
#  '2803',
#  '806',
#  '3205',
#  '3040',
#  '3143',
#  '1250',
#  '1981',
#  '4638',
#  '2761',
#  '2541',
#  '3236',
#  '745',
#  '3235',
#  '3945',
#  '3117',
#  '3187',
#  '2699',
#  '1343',
#  '3685',
#  '3860',
#  '2818',
#  '3028',
#  '3005',
#  '2424',
#  '2292',
#  '1168',
#  '4575',
#  '3278',
#  '3155',
#  '840',
#  '3533',
#  '4024',
#  '2964',
#  '4410',
#  '2671',
#  '3113',
#  '4085',
#  '2082',
#  '2216',
#  '4022',
#  '2048',
#  '1295',
#  '3773',
#  '1521',
#  '3862',
#  '3329',
#  '3714',
#  '4520',
#  '1430',
#  '3736',
#  '3842',
#  '2746',
#  '2475',
#  '500',
#  '2946',
#  '560',
#  '3927',
#  '2060',
#  '2074',
#  '4400',
#  '1285',
#  '2362',
#  '3475',
#  '2982',
#  '3253',
#  '3760',
#  '4041',
#  '765',
#  '2300',
#  '3108',
#  '1370',
#  '3263',
#  '3653',
#  '1156',
#  '3295',
#  '4026',
#  '2660',
#  '4035',
#  '2798',
#  '3300',
#  '3618',
#  '4990',
#  '3046',
#  '2567',
#  '1785',
#  '2857',
#  '2531',
#  '3982',
#  '3153',
#  '2417',
#  '3524',
#  '2536',
#  '3029',
#  '855',
#  '3078',
#  '2971',
#  '780',
#  '3510',
#  '3519',
#  '2038',
#  '3470',
#  '3610',
#  '3608',
#  '3837',
#  '4636',
#  '2482',
#  '3197',
#  '3416',
#  '3097',
#  '1870',
#  '2144',
#  '2365',
#  '1888',
#  '2715',
#  '2555',
#  '1790',
#  '3464',
#  '1922',
#  '2045',
#  '2551',
#  '4062',
#  '4455',
#  '2500',
#  '3590',
#  '2844',
#  '1542',
#  '4279',
#  '3823',
#  '2886',
#  '4464',
#  '1440',
#  '2036',
#  '3019',
#  '2380',
#  '1635',
#  '3442',
#  '3911',
#  '3859',
#  '2406',
#  '1184',
#  '3385',
#  '3149',
#  '4767',
#  '1879',
#  '4570',
#  '1363',
#  '4870',
#  '3030',
#  '3967',
#  '3159',
#  '1354',
#  '3814',
#  '1733',
#  '1142',
#  '3696',
#  '2458',
#  '3703',
#  '3399',
#  '3537',
#  '4018',
#  '3727',
#  '4148',
#  '3301',
#  '2100',
#  '3458',
#  '1170',
#  '2508',
#  '935',
#  '2969',
#  '566',
#  '2262',
#  '2303',
#  '917',
#  '4265',
#  '3039',
#  '3424',
#  '3000',
#  '1502',
#  '1892',
#  '937',
#  '3044',
#  '3299',
#  '2353',
#  '3154',
#  '3632',
#  '4102',
#  '4056',
#  '1750',
#  '822',
#  '2313',
#  '4532',
#  '3707',
#  '838',
#  '3949',
#  '2104',
#  '3233',
#  '2487',
#  '2444',
#  '2179',
#  '2484',
#  '740',
#  '2426',
#  '2647',
#  '3237',
#  '4249',
#  '1115',
#  '4147',
#  '3118',
#  '3012',
#  '2737',
#  '2472',
#  '1974',
#  '1395',
#  '2095',
#  '2278',
#  '3573',
#  '3267',
#  '3568',
#  '1740',
#  '3855',
#  '4820',
#  '2136',
#  '3551',
#  '3058',
#  '1536',
#  '4391',
#  '1616',
#  '3986',
#  '3362',
#  '1190',
#  '2780',
#  '3718',
#  '4037',
#  '2650',
#  '1748',
#  '3001',
#  '2152',
#  '3802',
#  '2700',
#  '4257',
#  '3436',
#  '1465',
#  '2935',
#  '1830',
#  '3570',
#  '2841',
#  '3970',
#  '4660',
#  '675',
#  '3167',
#  '2448',
#  '3555',
#  '2236',
#  '2885',
#  '2186',
#  '4100',
#  '4260',
#  '3105',
#  '1994',
#  '3791',
#  '2872',
#  '1574',
#  '2684',
#  '3916',
#  '1290',
#  '4227',
#  '3654',
#  '4017',
#  '2977',
#  '3180',
#  '3766',
#  '3184',
#  '3374',
#  '3993',
#  '2572',
#  '2128',
#  '2223',
#  '4485',
#  '2518',
#  '2997',
#  '4145',
#  '3547',
#  '2853',
#  '2779',
#  '3479',
#  '2709',
#  '3103',
#  '2605',
#  '1095',
#  '2220',
#  '3747',
#  '3873',
#  '3354',
#  '3259',
#  '2268',
#  '2281',
#  '4301',
#  '2862',
#  '2129',
#  '2420',
#  '3466',
#  '2976',
#  '1364',
#  '3754',
#  '2334',
#  '3292',
#  '850',
#  '2864',
#  '3755',
#  '3276',
#  '3636',
#  '1340',
#  '980',
#  '3234',
#  '2683',
#  '4198',
#  '2039',
#  '3644',
#  '2280',
#  '4180',
#  '2143',
#  '4480',
#  '2431',
#  '1992',
#  '4047',
#  '3687',
#  '2471',
#  '3663',
#  '1431',
#  '2874',
#  '2287',
#  '2118',
#  '3607',
#  '1664',
#  '3165',
#  '1452',
#  '4305',
#  '3717',
#  '3099',
#  '3051',
#  '4013',
#  '1088',
#  '3875',
#  '2849',
#  '4178',
#  '1062',
#  '815',
#  '1544',
#  '2070',
#  '2958',
#  '2355',
#  '2348',
#  '1227',
#  '2286',
#  '3925',
#  '1004',
#  '2774',
#  '3682',
#  '3807',
#  '3115',
#  '2442',
#  '1890',
#  '4612',
#  '2618',
#  '2116',
#  '3669',
#  '4205',
#  '3212',
#  '2657',
#  '1678',
#  '1090',
#  '3423',
#  '1327',
#  '4476',
#  '1405',
#  '2243',
#  '4825',
#  '2876',
#  '1723',
#  '4315',
#  '2372',
#  '4505',
#  '4950',
#  '2812',
#  '2564',
#  '3612',
#  '3772',
#  '1206',
#  '3033',
#  '4695',
#  '3659',
#  '2745',
#  '2600',
#  '1510',
#  '3415',
#  '3941',
#  '4655',
#  '1960',
#  '1831',
#  '1350',
#  '4005',
#  '3894',
#  '2725',
#  '3920',
#  '2981',
#  '2831',
#  '982',
#  '2474',
#  '3556',
#  '4355',
#  '4452',
#  '3201',
#  '2945',
#  '2970',
#  '1926',
#  '3013',
#  '1505',
#  '3397',
#  '1814',
#  '695',
#  '3189',
#  '4390',
#  '2530',
#  '722',
#  '1490',
#  '3539',
#  '3034',
#  '1865',
#  '2988',
#  '4076',
#  '3380',
#  '3252',
#  '3815',
#  '2340',
#  '3481',
#  '1670',
#  '2580',
#  '2973',
#  '3434',
#  '2522',
#  '4206',
#  '3179',
#  '1445',
#  '580',
#  '2923',
#  '3368',
#  '2913',
#  '2075',
#  '666',
#  '4027',
#  '3490',
#  '3966',
#  '1956',
#  '646',
#  '3052',
#  '1099',
#  '4595',
#  '2272',
#  '1806',
#  '3411',
#  '3601',
#  '2240',
#  '2465',
#  '1238',
#  '3650',
#  '2436',
#  '3552',
#  '2198',
#  '1778',
#  '4045',
#  '1975',
#  '2234',
#  '1488',
#  '3240',
#  '2028',
#  '1932',
#  '1530',
#  '3055',
#  '2637',
#  '3702',
#  '2734',
#  '3023',
#  '3614',
#  '1986',
#  '4140',
#  '1300',
#  '2212',
#  '1909',
#  '2573',
#  '1468',
#  '3640',
#  '3670',
#  '1310',
#  '2579',
#  '2898',
#  '3075',
#  '1675',
#  '1010',
#  '800',
#  '1702',
#  '3388',
#  '864',
#  '2790',
#  '3796',
#  '2918',
#  '2411',
#  '525',
#  '3797',
#  '2193',
#  '4114',
#  '3011',
#  '1066',
#  '2611',
#  '2563',
#  '1410',
#  '2747',
#  '3780',
#  '2753',
#  '4091',
#  '520',
#  '2108',
#  '3643',
#  '1842',
#  '3072',
#  '950',
#  '3785',
#  '2364',
#  '2739',
#  '3904',
#  '2718',
#  '4332',
#  '3603',
#  '2916',
#  '2040',
#  '2044',
#  '622',
#  '1225',
#  '1438',
#  '1070',
#  '3878',
#  '4700',
#  '2659',
#  '4602',
#  '3990',
#  '1015',
#  '3371',
#  '2738',
#  '944',
#  '4252',
#  '2517',
#  '2356',
#  '2294',
#  '3806',
#  '945',
#  '1998',
#  '2188',
#  '4618',
#  '4627',
#  '2032',
#  '3122',
#  '2308',
#  '2490',
#  '3781',
#  '4328',
#  '3566',
#  '2047',
#  '2389',
#  '4302',
#  '3021',
#  '3280',
#  '3646',
#  '3912',
#  '3737',
#  '2102',
#  '3624',
#  '3343',
#  '3745',
#  '1848',
#  '3417',
#  '3446',
#  '2449',
#  '3318',
#  '4432',
#  '4172',
#  '3866',
#  '2078',
#  '3882',
#  '3886',
#  '504',
#  '3589',
#  '1552',
#  '1885',
#  '2846',
#  '2208',
#  '2466',
#  '3163',
#  '3870',
#  '2621',
#  '4109',
#  '2148',
#  '2544',
#  '3701',
#  '2003',
#  '4073',
#  '3883',
#  '2180',
#  '2856',
#  '2985',
#  '3564',
#  '2383',
#  '2068',
#  '2519',
#  '1118',
#  '964',
#  '3306',
#  '3349',
#  '2546',
#  '3914',
#  '2080',
#  '1335',
#  '1424',
#  '2755',
#  '3344',
#  '1384',
#  '2139',
#  '3337',
#  '4194',
#  '3734',
#  '2829',
#  '1625',
#  '2949',
#  '2391',
#  '2296',
#  '3598',
#  '4104',
#  '3522',
#  '3291',
#  '4986',
#  '4055',
#  '3346',
#  '1634',
#  '3386',
#  '2395',
#  '3549',
#  '632',
#  '962',
#  '3638',
#  '4420',
#  '3077',
#  '1965',
#  '3485',
#  '4490',
#  '4454',
#  '2174',
#  '1756',
#  '585',
#  '1320',
#  '3853',
#  '3872',
#  '3649',
#  '2284',
#  '3140',
#  '1972',
#  '4237',
#  '754',
#  '1680',
#  '1418',
#  '755',
#  '1048',
#  '1159',
#  '3812',
#  '825',
#  '2255',
#  '1602',
#  '955',
#  '2399',
#  '4340',
#  '4720',
#  '3648',
#  '2405',
#  '3611',
#  '3066',
#  '2326',
#  '1829',
#  '2352',
#  '2464',
#  '3310',
#  '2963',
#  '1900',
#  '1808',
#  '2858',
#  '3333',
#  '2631',
#  '1268',
#  '4694',
#  '1275',
#  '4015',
#  '2634',
#  '2516',
#  '4425',
#  '2967',
#  '2403',
#  '3874',
#  '4272',
#  '4261',
#  '3043',
#  '3929',
#  '1508',
#  '2239',
#  '2491',
#  '3683',
#  '3798',
#  '2034',
#  '2980',
#  '956',
#  '860',
#  '3070',
#  '2528',
#  '4760',
#  '3783',
#  '4888',
#  '4042',
#  '4218',
#  '1120',
#  '884',
#  '2804',
#  '2050',
#  '3238',
#  '2830',
#  '3497',
#  '706',
#  '2371',
#  '812',
#  '1640',
#  '1978',
#  '3673',
#  '2166',
#  '2897',
#  '3020',
#  '3120',
#  '3224',
#  '2901',
#  '565',
#  '2138',
#  '3059',
#  '1955',
#  '3142',
#  '4318',
#  '3902',
#  '4275',
#  '3173',
#  '4068',
#  '3623',
#  '3054',
#  '3330',
#  '1809',
#  '3290',
#  '1977',
#  '725',
#  '778',
#  '3732',
#  '1348',
#  '1029',
#  '3325',
#  ...]
